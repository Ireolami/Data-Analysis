# %%
pip install tweepy
# Out:
# ...
#   Obtaining dependency information for tweepy from https://files.pythonhosted.org/packages/4d/78/ba0065d5636bbf4a35b78c4f81b74e7858b609cdf69e629d6da5c91b9d92/tweepy-4.14.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for oauthlib<4,>=3.2.0 from https://files.pythonhosted.org/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for requests-oauthlib<2,>=1.2.0 from https://files.pythonhosted.org/packages/6f/bb/5deac77a9af870143c684ab46a7934038a53eb4aa975bc0687ed6ca2c610/requests_oauthlib-1.3.1-py2.py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 kB 470.3 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 1.0 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Api-Key
#LnE70nTWLBj8gNzsZLqTg0fc2

# %%
#Key Secret
#FQNce84atuSGWbX3iToGZehVs16khgc4lQuXKjHnomU7pC1cNo

#Access Token
#1449605225627766785-G1MtfkAlFMkfWqGn9UNkuDDBhbKbjh
#Access Token Secret
#TyNGAe8UIFuxDto0sYb1MafFdBnE9VTDO0uXOoYn7HAkk

# %%
import tweepy


API_KEY = 'LnE70nTWLBj8gNzsZLqTg0fc2'
API_SECRET_KEY = 'FQNce84atuSGWbX3iToGZehVs16khgc4lQuXKjHnomU7pC1cNo'
ACCESS_TOKEN = '1449605225627766785-G1MtfkAlFMkfWqGn9UNkuDDBhbKbjh'
ACCESS_TOKEN_SECRET = 'TyNGAe8UIFuxDto0sYb1MafFdBnE9VTDO0uXOoYn7HAkk'

# Authenticate
auth = tweepy.OAuthHandler(API_KEY, API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# Fetch tweets
query = "COVID-19 OR coronavirus OR pandemic -filter:retweets"
tweets = tweepy.Cursor(api.search_tweets, q=query, lang="en", tweet_mode='extended').items(100)

# Extract text
tweet_list = [tweet.full_text for tweet in tweets]
print(tweet_list[:5])
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[4], line 19
#      16 tweets = tweepy.Cursor(api.search_tweets, q=query, lang="en", tweet_mode='extended').items(100)
#      18 # Extract text
# ---> 19 tweet_list = [tweet.full_text for tweet in tweets]
#      20 print(tweet_list[:5])
#
# Cell In[4], line 19, in <listcomp>(.0)
#      16 tweets = tweepy.Cursor(api.search_tweets, q=query, lang="en", tweet_mode='extended').items(100)
#      18 # Extract text
# ---> 19 tweet_list = [tweet.full_text for tweet in tweets]
#      20 print(tweet_list[:5])
#
# File ~/anaconda3/lib/python3.11/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/anaconda3/lib/python3.11/site-packages/tweepy/cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
# ...

# %%
#Bearer_token
#AAAAAAAAAAAAAAAAAAAAAIOLxQEAAAAA6GgU8VyhbN6xVpYtkzCr5FCHA00%3DOW09j23hnMR4UHc6zpnbtUJLcPQ9piUSXR97Bp5zzuFMDn31Tk

# %%
import requests

# Bearer Token
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAIOLxQEAAAAA6GgU8VyhbN6xVpYtkzCr5FCHA00%3DOW09j23hnMR4UHc6zpnbtUJLcPQ9piUSXR97Bp5zzuFMDn31Tk"

# Endpoint and Query
url = "https://api.twitter.com/2/tweets/search/recent"
query_params = {
    'query': 'covid19',  # Replace with your desired query
    'max_results': 10
}

# Headers
headers = {
    "Authorization": f"Bearer {BEARER_TOKEN}"
}

# API Request
response = requests.get(url, headers=headers, params=query_params)

if response.status_code == 200:
    tweets = response.json()
    for tweet in tweets.get('data', []):
        print(tweet['text'])
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# #COVID19 #ID2020 #pandemia #GreatReset #Transhumanismo #Espana #España #CampoDeConcentraciónGlobal #Auschwitz #Agenda2030 #OMS #BillGates
# @davidicke
#
# @DraPatriciaDeNa
#
# @ainhoabilboa
#
# @JuezLopezMDP
#
# @JulioRazona
#
# @veronicaressia
#
# @leogbayona
#
# @Xar_Crystal
#
# @ulises37
#
# @tatious_… https://t.co/by8DrWOFaf https://t.co/LU4PUCcqKf
# RT @Excelsior: 🚨☣️ México registró 683 decesos y 14 mil 017 casos confirmados de #Covid19, hasta el pasado 30 de noviembre.
#
# https://t.co/E…
# RT @MSGAllTrading: MSG 9 bar 9 Hair oil is rich in vitamin B-7, or biotin, which helps to keep hair strong &amp; healthy. It can also help prot…
# RT @Sanjay_Dixit: JNU scientists including @ARanganathan72 make big discovery that could change malaria Covid19 treatment https://t.co/CeYP…
# RT @Sanjay_Dixit: JNU scientists including @ARanganathan72 make big discovery that could change malaria Covid19 treatment https://t.co/CeYP…
# ...

# %%
import pandas as pd

# %%
data= pd.read_csv('biweekly_cases_per_million.csv')
data.tail()
# Out:
#             date   World  Afghanistan  Africa  Albania  Algeria  \
# 1669  2024-07-31  13.530          0.0   0.191      0.0    0.836
# 1670  2024-08-01  13.530          0.0   0.191      0.0    0.836
# 1671  2024-08-02  13.530          0.0   0.191      0.0    0.836
# 1672  2024-08-03  13.530          0.0   0.191      0.0    0.836
# 1673  2024-08-04  12.915          0.0   0.118      0.0    0.528
#
#       American Samoa  Andorra  Angola  Anguilla  ...  Uruguay  Uzbekistan  \
# 1669             0.0      0.0     0.0       0.0  ...    7.078         0.0
# 1670             0.0      0.0     0.0       0.0  ...    7.078         0.0
# 1671             0.0      0.0     0.0       0.0  ...    7.078         0.0
# 1672             0.0      0.0     0.0       0.0  ...    7.078         0.0
# 1673             0.0      0.0     0.0       0.0  ...    7.962         0.0
#
#       Vanuatu  Vatican  Venezuela  Vietnam  Wallis and Futuna  Yemen  Zambia  \
# ...

# %%
data
# Out:
#             date   World  Afghanistan  Africa  Albania  Algeria  \
# 0     2020-01-05     NaN          NaN     NaN      NaN      NaN
# 1     2020-01-06     NaN          NaN     NaN      NaN      NaN
# 2     2020-01-07     NaN          NaN     NaN      NaN      NaN
# 3     2020-01-08     NaN          NaN     NaN      NaN      NaN
# 4     2020-01-09     NaN          NaN     NaN      NaN      NaN
# ...          ...     ...          ...     ...      ...      ...
# 1669  2024-07-31  13.530          0.0   0.191      0.0    0.836
# 1670  2024-08-01  13.530          0.0   0.191      0.0    0.836
# 1671  2024-08-02  13.530          0.0   0.191      0.0    0.836
# 1672  2024-08-03  13.530          0.0   0.191      0.0    0.836
# 1673  2024-08-04  12.915          0.0   0.118      0.0    0.528
#
#       American Samoa  Andorra  Angola  Anguilla  ...  Uruguay  Uzbekistan  \
# 0                NaN      NaN     NaN       NaN  ...      NaN         NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1674 entries, 0 to 1673
# Columns: 247 entries, date to Zimbabwe
# dtypes: float64(246), object(1)
# memory usage: 3.2+ MB

# %%
data.describe()
# Out:
#              World  Afghanistan       Africa      Albania      Algeria  \
# count  1662.000000  1662.000000  1662.000000  1662.000000  1662.000000
# mean    818.047384    48.827072    76.568851   998.119361    50.403632
# std    1195.812974    89.904923   104.999984  1679.220074    87.882378
# min       0.006000     0.000000     0.000000     0.000000     0.000000
# 25%      65.095250    10.824250     2.266500    15.207500     0.418000
# 50%     603.800000    18.138000    27.224000    95.487000     3.188000
# 75%    1021.380000    48.892000   109.142000  1416.742000    63.394000
# max    9008.222000   600.288000   436.153000  9724.096000   523.909000
#
#        American Samoa       Andorra       Angola      Anguilla  \
# count     1662.000000   1662.000000  1662.000000   1662.000000
# mean      1455.861777   5073.360968    25.406900   2315.566811
# std       6897.765257  10981.534497    57.312977   4984.787379
# min          0.000000      0.000000     0.000000      0.000000
# ...
